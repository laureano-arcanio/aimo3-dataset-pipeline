# %% [markdown]
# ## Setup

# %%
import pandas as pd
import json
import re
import subprocess
import tempfile
import os
import sys
import time
from pathlib import Path
from datetime import datetime
from functools import partial

import anyio
from tqdm.notebook import tqdm

# Add pipeline directory to path to import llm_pool and runtime_config
sys.path.insert(0, str(Path.cwd().parent / 'pipeline'))
sys.path.insert(0, str(Path.cwd().parent / 'datasets'))
import importlib
import llm_pool, runtime_config
importlib.reload(llm_pool)
importlib.reload(runtime_config)
from llm_pool import LLMPool
from runtime_config import RuntimeConfig

# %% [markdown]
# ## Configuration

# %%
# API Configuration
API_BASE_URL = "http://127.0.0.1:8080/v1"
API_KEY = "sk-local"
MODEL_NAME = "qwen"

# Evaluation Configuration
KEEP_ONLY = True # only use audited to "keep"
N_PROBLEMS = 0

# Test file
TEST_PATH = Path('/home/larcanio/AIMO3_v2/data/datasets/splits/gemma_balanced/test.jsonl')
# Optional: use GSM8K test.jsonl directly (set to None to use the normalized format below)
GSM8K_TEST_FILE = None #'/home/larcanio/AIMO3_v2/data/GSM8I/test.jsonl'

# Generation Parameters
MAX_TOKENS = 1024
GREEDY_TEMPERATURE = 0
GREEDY_TOP_P = 1.0
SAMPLED_TEMPERATURE = 0.6
SAMPLED_TOP_P = 0.8
N_SAMPLES = 3

# Output Configuration
DATASET_NAME = "gemma_balanced"
OUTPUT_DIR = Path("./evaluations")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Live-tunable settings (edit config.json while running)
CONFIG_FILE = "config.json"
cfg = RuntimeConfig(CONFIG_FILE, defaults={
    "MAX_CONCURRENT": 10,
    "EXECUTION_TIMEOUT": 30,
    "REQUEST_TIMEOUT": 50,
    "SAVE_EVERY": 200,
})

print(f"Model: {MODEL_NAME}")
print(f"Evaluating {N_PROBLEMS} problems")
print(f"GSM8K test file: {GSM8K_TEST_FILE}")
print(f"Output: {OUTPUT_DIR}")
print(cfg)
# Out:
# Model: qwen
# Evaluating 0 problems
# GSM8K test file: None
# Output: evaluations
# RuntimeConfig(MAX_CONCURRENT=10, EXECUTION_TIMEOUT=30, REQUEST_TIMEOUT=50, SAVE_EVERY=200)

# %% [markdown]
# ## Load Evaluation Dataset

# %%
if GSM8K_TEST_FILE is not None:
    # Load GSM8K test.jsonl directly: {"question": "...", "answer": "reasoning\n#### number"}
    datapoints = []
    with open(GSM8K_TEST_FILE, 'r', encoding='utf-8') as f:
        for i, line in enumerate(f):
            if not line.strip():
                continue
            dp = json.loads(line)
            answer_text = dp['answer']
            if '####' not in answer_text:
                continue
            numeric_str = answer_text.split('####')[-1].strip().replace(',', '')
            numeric_match = re.search(r'-?\d+\.?\d*', numeric_str)
            if not numeric_match:
                continue
            datapoints.append({
                'problem_id': str(i),
                'problem': dp['question'],
                'answer': numeric_match.group(),
                'domain': 'unknown',
                'level': -1,
            })
    print(f"Loaded {len(datapoints)} problems from GSM8K test file")
else:
    # Load evaluation dataset (normalized format)
    jsonl_file = TEST_PATH

    datapoints = []
    with open(jsonl_file, 'r', encoding='utf-8') as f:
        for line in f:
            if line.strip():
                try:
                    dp = json.loads(line)
                    datapoints.append({
                        'problem_id': dp['problem_id'],
                        'problem': dp["problem"]['text'],
                        'answer': dp["problem"]['expected_answer'],
                        'domain': dp.get('math_structure', {}).get('from_text', {}).get('domain', 'unknown'),
                        'level': min((b['level'] for b in dp.get('computation_buckets', []) if b.get('passes', 0) > 0), default=-1),
                    })
                except json.JSONDecodeError:
                    continue

if N_PROBLEMS > 0:
    eval_df = pd.DataFrame(datapoints).head(N_PROBLEMS).reset_index(drop=True)
else:
    eval_df = pd.DataFrame(datapoints).reset_index(drop=True)

print(f"Loaded {len(eval_df)} problems")
print(f"Domains: {eval_df['domain'].value_counts().to_dict()}")
print(f"Levels:  {eval_df['level'].value_counts().sort_index().to_dict()}")
print(f"Sample: {eval_df.iloc[0]['problem'][:100]}...")
# Out:
# Loaded 492 problems
# Domains: {'algebra': 246, 'geometry': 99, 'combinatorics': 98, 'number_theory': 49}
# Levels:  {1: 55, 2: 255, 3: 182}
# Sample: Joe’s mother gave him $56 to go to the store. Joe bought 7 notebooks and 2 books. Each notebook cost...

# %% [markdown]
# ## Code Extraction & Execution

# %%
import signal


def extract_code_from_response(text):
    if not text:
        return None
    for pattern in [r'```python\s*(.*?)\s*```', r'```\s*(.*?)\s*```']:
        match = re.search(pattern, text, re.DOTALL)
        if match:
            return match.group(1).strip()
    return None


def _kill_proc_tree(proc):
    """Kill a process and its entire process group, then close pipes."""
    # Kill the whole process group so orphan children can't hold pipes open
    try:
        os.killpg(os.getpgid(proc.pid), signal.SIGKILL)
    except OSError:
        try:
            proc.kill()
        except OSError:
            pass
    # Close pipe handles so wait() can't block on lingering children
    for pipe in (proc.stdout, proc.stderr, proc.stdin):
        if pipe:
            try:
                pipe.close()
            except OSError:
                pass
    try:
        proc.wait(timeout=5)
    except Exception:
        pass


def execute_code_with_timeout(code: str, timeout_seconds: int = 30):
    """Execute code in a fresh subprocess with proper process-group cleanup.

    Uses Popen + start_new_session so we can killpg() the entire tree
    if the process (or its children) exceeds the timeout.  This prevents
    orphan child processes from holding stdout/stderr pipes open and
    blocking the calling thread indefinitely.
    """
    tmp_path = None
    start_time = time.time()
    proc = None
    try:
        with tempfile.NamedTemporaryFile(mode='w', suffix='.py', delete=False) as f:
            f.write(code)
            tmp_path = f.name

        proc = subprocess.Popen(
            [sys.executable, tmp_path],
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True,
            start_new_session=True,   # new process group → killpg works
        )

        try:
            stdout, stderr = proc.communicate(timeout=timeout_seconds)
        except subprocess.TimeoutExpired:
            _kill_proc_tree(proc)
            duration = time.time() - start_time
            return None, f"Timeout after {timeout_seconds}s", True, duration

        duration = time.time() - start_time

        if proc.returncode != 0:
            return None, (stderr or "")[:500] or "Non-zero exit", False, duration
        stdout = (stdout or "").strip()
        if stdout:
            result = stdout.split('\n')[-1].strip()
            return result, None, False, duration
        return None, "No output", False, duration
    except Exception as e:
        if proc is not None:
            _kill_proc_tree(proc)
        duration = time.time() - start_time
        return None, str(e)[:500], False, duration
    finally:
        if tmp_path:
            try:
                os.unlink(tmp_path)
            except OSError:
                pass


def check_answer(predicted, expected):
    if predicted is None or expected is None:
        return False
    pred_str = str(predicted).strip()
    exp_str = str(expected).strip()
    if pred_str == exp_str:
        return True
    try:
        return abs(float(pred_str) - float(exp_str)) < 1e-6
    except (ValueError, TypeError):
        return False

print("Utils loaded")
# Out:
# Utils loaded

# %% [markdown]
# ## Prompt Template

# %%
SYSTEM_MESSAGE = "You are a mathematician writing Python code to solve problems."

def format_prompt(problem: str) -> str:
    return f"""Write a Python program that computes the correct answer to the following math problem.

Requirements:
- The program must compute the answer programmatically (do NOT hard-code the final value).
- The program must be fully self-contained and executable.
- The program must print ONLY the final numerical answer (no extra text).

Output format:
- Output exactly one Python code block, starting with ```python and ending with ```.
- Do not include any text outside the code block.

Problem:
{problem}"""

# %% [markdown]
# ## Evaluation Engine

# %%
async def evaluate_single_problem(pool: LLMPool, problem_row: dict, idx: int,
                                  exec_limiter: anyio.CapacityLimiter | None = None,
                                  verbose: bool = False):
    problem_id = problem_row['problem_id']
    problem_text = problem_row['problem']
    expected_answer = str(problem_row['answer'])
    
    if verbose:
        print(f"[{idx}] Starting problem {problem_id}", flush=True)
    
    prompt = format_prompt(problem_text)
    messages = [
        # {"role": "system", "content": SYSTEM_MESSAGE},
        {"role": "user", "content": prompt}
    ]
    
    record = {
        'problem_id': problem_id,
        'problem': problem_text,
        'answer': expected_answer,
        'domain': problem_row.get('domain', 'unknown'),
        'level': problem_row.get('level', -1),
    }
    
    tok_in = 0
    tok_out = 0

    async def _run_code(code: str):
        """Run code in a thread, gated by exec_limiter to prevent thread-pool exhaustion."""
        if exec_limiter is not None:
            async with exec_limiter:
                return await anyio.to_thread.run_sync(
                    partial(execute_code_with_timeout, code, cfg.EXECUTION_TIMEOUT)
                )
        return await anyio.to_thread.run_sync(
            partial(execute_code_with_timeout, code, cfg.EXECUTION_TIMEOUT)
        )
    
    # Greedy Pass@1
    try:
        resp = await pool.request(messages, temperature=GREEDY_TEMPERATURE, max_tokens=MAX_TOKENS, top_p=GREEDY_TOP_P)
        tok_in += resp.prompt_tokens
        tok_out += resp.completion_tokens
        code = extract_code_from_response(resp.content)
        record['code_greedy'] = code
        if code:
            result, error, is_timeout, duration = await _run_code(code)
            record['exec_ok_greedy'] = (error is None and not is_timeout)
            record['result_greedy'] = result
            record['error_greedy'] = error
            record['correct_greedy'] = check_answer(result, expected_answer)
        else:
            record['exec_ok_greedy'] = False
            record['result_greedy'] = None
            record['error_greedy'] = "No code"
            record['correct_greedy'] = False
    except Exception as e:
        print(f"LLM error (problem {idx}, greedy): {type(e).__name__} - {str(e)[:200]}", flush=True)
        record['code_greedy'] = None
        record['exec_ok_greedy'] = False
        record['result_greedy'] = None
        record['error_greedy'] = f"API error: {str(e)}"
        record['correct_greedy'] = False
    
    # Sampled Pass@N — early exit on first correct
    for sample_idx in range(1, N_SAMPLES + 1):
        try:
            resp = await pool.request(messages, temperature=SAMPLED_TEMPERATURE, max_tokens=MAX_TOKENS, top_p=SAMPLED_TOP_P)
            tok_in += resp.prompt_tokens
            tok_out += resp.completion_tokens
            code = extract_code_from_response(resp.content)
            record[f'code_{sample_idx}'] = code
            if code:
                result, error, is_timeout, duration = await _run_code(code)
                record[f'exec_ok_{sample_idx}'] = (error is None and not is_timeout)
                record[f'result_{sample_idx}'] = result
                record[f'error_{sample_idx}'] = error
                record[f'correct_{sample_idx}'] = check_answer(result, expected_answer)
            else:
                record[f'exec_ok_{sample_idx}'] = False
                record[f'result_{sample_idx}'] = None
                record[f'error_{sample_idx}'] = "No code"
                record[f'correct_{sample_idx}'] = False
        except Exception as e:
            print(f"LLM error (problem {idx}, sample {sample_idx}): {type(e).__name__} - {str(e)[:200]}", flush=True)
            record[f'code_{sample_idx}'] = None
            record[f'exec_ok_{sample_idx}'] = False
            record[f'result_{sample_idx}'] = None
            record[f'error_{sample_idx}'] = f"API error: {str(e)}"
            record[f'correct_{sample_idx}'] = False
        
        # Early exit: no need for more samples once we have a pass
        if record.get(f'correct_{sample_idx}', False):
            for remaining in range(sample_idx + 1, N_SAMPLES + 1):
                record[f'code_{remaining}'] = None
                record[f'exec_ok_{remaining}'] = False
                record[f'result_{remaining}'] = None
                record[f'error_{remaining}'] = "Skipped (early exit)"
                record[f'correct_{remaining}'] = False
            break
    
    # Derived metrics
    record['pass@1'] = record['correct_greedy']
    record['pass@3'] = any([record.get(f'correct_{j}', False) for j in range(1, N_SAMPLES + 1)])
    record['first_success_attempt'] = None
    for j in range(1, N_SAMPLES + 1):
        if record.get(f'correct_{j}', False):
            record['first_success_attempt'] = j
            break
    
    return record, tok_in, tok_out


async def run_evaluation(eval_df: pd.DataFrame):
    results = []
    completed = 0
    pass1_count = 0
    pass2_count = 0
    pass3_count = 0
    total_tok_in = 0
    total_tok_out = 0
    max_problems = len(eval_df)
    
    pbar = tqdm(total=max_problems, desc="Evaluating")
    write_lock = anyio.Lock()
    # Limit live coroutines so the event loop stays responsive
    spawn_limit = anyio.Semaphore(cfg.MAX_CONCURRENT * 3)
    # Cap concurrent subprocess executions to avoid thread-pool exhaustion.
    # Each problem may run up to (1 + N_SAMPLES) code executions, so we limit
    # total threads consumed by subprocesses independently of coroutine count.
    exec_limiter = anyio.CapacityLimiter(cfg.MAX_CONCURRENT * 2)
    
    async def process_one_with_progress(pool, idx, row):
        nonlocal completed, pass1_count, pass2_count, pass3_count
        nonlocal total_tok_in, total_tok_out
        
        t0 = time.monotonic()
        result, tok_in, tok_out = await evaluate_single_problem(
            pool, row.to_dict(), idx, exec_limiter=exec_limiter
        )
        elapsed = time.monotonic() - t0
        
        async with write_lock:
            results.append(result)
            completed += 1
            total_tok_in += tok_in
            total_tok_out += tok_out
            
            if result.get('correct_greedy', False):
                pass1_count += 1
            if any([result.get(f'correct_{j}', False) for j in range(1, min(3, N_SAMPLES + 1))]):
                pass2_count += 1
            if any([result.get(f'correct_{j}', False) for j in range(1, N_SAMPLES + 1)]):
                pass3_count += 1
            
            pbar.set_postfix({
                'P@1': f'{pass1_count}/{completed} ({pass1_count/completed*100:.1f}%)',
                'P@2': f'{pass2_count}/{completed} ({pass2_count/completed*100:.1f}%)',
                'P@3': f'{pass3_count}/{completed} ({pass3_count/completed*100:.1f}%)'
            })
            pbar.update(1)
            
            status = "Pass" if result['pass@1'] else "Fail"
            print(
                f"{completed}/{max_problems} -> {status}"
                f" -> P@1={result['pass@1']}, P@3={result['pass@3']},"
                f" req={elapsed:.1f}s,"
                f" tokens: in={tok_in}, out={tok_out}, total={tok_in+tok_out}",
                flush=True
            )
    
    async with LLMPool(
        base_url=API_BASE_URL,
        api_key=API_KEY,
        model=MODEL_NAME,
        max_inflight=cfg.MAX_CONCURRENT,
        timeout=cfg.REQUEST_TIMEOUT
    ) as pool:
        async with anyio.create_task_group() as tg:
            for idx, row in eval_df.iterrows():
                async def _run(pool=pool, idx=idx, row=row):
                    async with spawn_limit:
                        await process_one_with_progress(pool, idx, row)
                tg.start_soon(_run)
    
    pbar.close()
    print(f"\nTotal tokens: in={total_tok_in}, out={total_tok_out}, total={total_tok_in+total_tok_out}")
    return results

print("Evaluation engine ready")
# Out:
# Evaluation engine ready

# %%
# Sync test - bypasses event loop entirely
import httpx as _httpx
with _httpx.Client(timeout=10) as c:
    r = c.post(f"{API_BASE_URL}/chat/completions", json={
        "model": MODEL_NAME,
        "messages": [{"role":"user","content":"2+2?"}],
        "max_tokens": 16, "temperature": 0.0,
    }, headers={"Authorization": f"Bearer {API_KEY}"})
    print(f"Status: {r.status_code}")
    print(r.json()["choices"][0]["message"]["content"])
# Out:
# Status: 200
# 2 + 2 = 4

# %%
# Quick connectivity test - run this first
import httpx

async def test_api():
    body = {
        "model": MODEL_NAME,
        "messages": [
            {"role": "user", "content": "What is 2+2? Reply with just the number."}
        ],
        "temperature": 0.0,
        "max_tokens": 32,
    }
    print(f"POST {API_BASE_URL}/chat/completions")
    print(f"model={MODEL_NAME}, timeout={cfg.REQUEST_TIMEOUT}s")
    
    async with httpx.AsyncClient(timeout=httpx.Timeout(30, connect=5)) as client:
        t0 = time.monotonic()
        try:
            resp = await client.post(
                f"{API_BASE_URL}/chat/completions",
                json=body,
                headers={"Authorization": f"Bearer {API_KEY}", "Content-Type": "application/json"},
            )
            elapsed = time.monotonic() - t0
            # print(f"Status: {resp.status_code} in {elapsed:.2f}s")
            if resp.status_code == 200:
                data = resp.json()
                print(f"Content: {data['choices'][0]['message']['content']}")
                print(f"Tokens: in={data.get('usage',{}).get('prompt_tokens')}, out={data.get('usage',{}).get('completion_tokens')}")
            else:
                print(f"Body: {resp.text[:500]}")
        except Exception as e:
            elapsed = time.monotonic() - t0
            print(f"FAILED after {elapsed:.2f}s: {type(e).__name__}: {e}")

await test_api()
# Out:
# POST http://127.0.0.1:8080/v1/chat/completions
# model=qwen, timeout=50s
# Content: 4
#
# Tokens: in=22, out=4

# %% [markdown]
# ## Run Evaluation

# %%
print(f"Starting evaluation of {len(eval_df)} problems")
print(f"Greedy: temp={GREEDY_TEMPERATURE}")
print(f"Sampled: temp={SAMPLED_TEMPERATURE}, n={N_SAMPLES}\n")

start_time = time.time()
results = await run_evaluation(eval_df)
elapsed = time.time() - start_time

print(f"\nCompleted in {elapsed:.1f}s ({elapsed/len(eval_df):.2f}s per problem)")
# Out:
# Starting evaluation of 492 problems
# Greedy: temp=0
# Sampled: temp=0.6, n=3
# Evaluating:   0%|          | 0/492 [00:00<?, ?it/s]
# 1/492 -> Pass -> P@1=True, P@3=True, req=4.8s, tokens: in=306, out=82, total=388
# 2/492 -> Fail -> P@1=False, P@3=True, req=5.3s, tokens: in=304, out=116, total=420
# 3/492 -> Pass -> P@1=True, P@3=True, req=5.8s, tokens: in=318, out=132, total=450
# 4/492 -> Pass -> P@1=True, P@3=True, req=6.9s, tokens: in=466, out=137, total=603
# 5/492 -> Pass -> P@1=True, P@3=True, req=7.0s, tokens: in=354, out=50, total=404
# 6/492 -> Fail -> P@1=False, P@3=True, req=7.5s, tokens: in=328, out=114, total=442
# 7/492 -> Fail -> P@1=False, P@3=True, req=9.0s, tokens: in=640, out=182, total=822
# 8/492 -> Pass -> P@1=True, P@3=True, req=10.5s, tokens: in=358, out=138, total=496
# 9/492 -> Fail -> P@1=False, P@3=True, req=12.5s, tokens: in=364, out=223, total=587
# 10/492 -> Pass -> P@1=True, P@3=True, req=9.6s, tokens: in=1578, out=61, total=1639
# 11/492 -> Fail -> P@1=False, P@3=False, req=14.7s, tokens: in=652, out=130, total=782
# 12/492 -> Fail -> P@1=False, P@3=False, req=15.7s, tokens: in=612, out=180, total=792
# 13/492 -> Fail -> P@1=False, P@3=True, req=16.5s, tokens: in=720, out=349, total=1069
# 14/492 -> Pass -> P@1=True, P@3=True, req=11.2s, tokens: in=1342, out=114, total=1456
# 15/492 -> Pass -> P@1=True, P@3=True, req=16.7s, tokens: in=657, out=392, total=1049
# 16/492 -> Fail -> P@1=False, P@3=False, req=17.9s, tokens: in=784, out=268, total=1052
# 17/492 -> Pass -> P@1=True, P@3=True, req=18.2s, tokens: in=543, out=234, total=777
# 18/492 -> Fail -> P@1=False, P@3=False, req=18.8s, tokens: in=796, out=252, total=1048
# 19/492 -> Fail -> P@1=False, P@3=True, req=19.0s, tokens: in=752, out=324, total=1076
# 20/492 -> Fail -> P@1=False, P@3=False, req=19.9s, tokens: in=632, out=203, total=835
# 21/492 -> Pass -> P@1=True, P@3=False, req=19.9s, tokens: in=708, out=294, total=1002
# 22/492 -> Pass -> P@1=True, P@3=True, req=13.2s, tokens: in=282, out=158, total=440
# 23/492 -> Fail -> P@1=False, P@3=False, req=22.3s, tokens: in=640, out=165, total=805
# 24/492 -> Fail -> P@1=False, P@3=False, req=22.8s, tokens: in=548, out=285, total=833
# 25/492 -> Fail -> P@1=False, P@3=False, req=23.1s, tokens: in=724, out=271, total=995
# 26/492 -> Fail -> P@1=False, P@3=False, req=23.4s, tokens: in=616, out=534, total=1150
# 27/492 -> Fail -> P@1=False, P@3=False, req=25.5s, tokens: in=1080, out=471, total=1551
# 28/492 -> Pass -> P@1=True, P@3=True, req=13.4s, tokens: in=368, out=96, total=464
# 29/492 -> Fail -> P@1=False, P@3=False, req=27.3s, tokens: in=1196, out=682, total=1878
# 30/492 -> Fail -> P@1=False, P@3=False, req=27.6s, tokens: in=664, out=587, total=1251
# 31/492 -> Pass -> P@1=True, P@3=True, req=13.0s, tokens: in=298, out=115, total=413
# 32/492 -> Fail -> P@1=False, P@3=True, req=13.0s, tokens: in=316, out=156, total=472
# 33/492 -> Pass -> P@1=True, P@3=True, req=12.2s, tokens: in=316, out=143, total=459
# 34/492 -> Fail -> P@1=False, P@3=False, req=23.5s, tokens: in=588, out=195, total=783
# 35/492 -> Pass -> P@1=True, P@3=True, req=11.7s, tokens: in=348, out=108, total=456
# 36/492 -> Pass -> P@1=True, P@3=True, req=16.2s, tokens: in=308, out=339, total=647
# 37/492 -> Pass -> P@1=True, P@3=True, req=11.1s, tokens: in=342, out=104, total=446
# 38/492 -> Fail -> P@1=False, P@3=False, req=34.4s, tokens: in=756, out=1153, total=1909
# 39/492 -> Fail -> P@1=False, P@3=True, req=15.0s, tokens: in=302, out=243, total=545
# 40/492 -> Fail -> P@1=False, P@3=False, req=28.3s, tokens: in=608, out=389, total=997
# 41/492 -> Fail -> P@1=False, P@3=False, req=26.5s, tokens: in=612, out=335, total=947
# 42/492 -> Pass -> P@1=True, P@3=True, req=12.2s, tokens: in=312, out=166, total=478
# 43/492 -> Fail -> P@1=False, P@3=False, req=21.9s, tokens: in=640, out=134, total=774
# 44/492 -> Fail -> P@1=False, P@3=False, req=20.1s, tokens: in=544, out=141, total=685
# 45/492 -> Fail -> P@1=False, P@3=False, req=31.9s, tokens: in=768, out=676, total=1444
# 46/492 -> Pass -> P@1=True, P@3=True, req=10.4s, tokens: in=370, out=200, total=570
# 47/492 -> Fail -> P@1=False, P@3=True, req=13.9s, tokens: in=552, out=165, total=717
# 48/492 -> Fail -> P@1=False, P@3=False, req=28.9s, tokens: in=844, out=585, total=1429
# 49/492 -> Pass -> P@1=True, P@3=True, req=10.6s, tokens: in=328, out=128, total=456
# 50/492 -> Pass -> P@1=True, P@3=True, req=10.5s, tokens: in=332, out=88, total=420
# 51/492 -> Fail -> P@1=False, P@3=False, req=22.4s, tokens: in=672, out=218, total=890
# 52/492 -> Fail -> P@1=False, P@3=False, req=42.6s, tokens: in=796, out=1515, total=2311
# 53/492 -> Fail -> P@1=False, P@3=False, req=42.8s, tokens: in=684, out=1404, total=2088
# 54/492 -> Fail -> P@1=False, P@3=False, req=23.7s, tokens: in=636, out=328, total=964
# 55/492 -> Fail -> P@1=False, P@3=False, req=20.9s, tokens: in=748, out=175, total=923
# 56/492 -> Fail -> P@1=False, P@3=False, req=27.4s, tokens: in=600, out=387, total=987
# 57/492 -> Fail -> P@1=False, P@3=False, req=28.8s, tokens: in=664, out=513, total=1177
# 58/492 -> Pass -> P@1=True, P@3=True, req=9.6s, tokens: in=314, out=90, total=404
# 59/492 -> Fail -> P@1=False, P@3=False, req=25.4s, tokens: in=560, out=445, total=1005
# 60/492 -> Pass -> P@1=True, P@3=True, req=12.8s, tokens: in=340, out=241, total=581
# 61/492 -> Pass -> P@1=True, P@3=True, req=10.0s, tokens: in=348, out=70, total=418
# 62/492 -> Fail -> P@1=False, P@3=False, req=21.1s, tokens: in=696, out=166, total=862
# 63/492 -> Fail -> P@1=False, P@3=False, req=20.2s, tokens: in=612, out=256, total=868
# 64/492 -> Pass -> P@1=True, P@3=True, req=11.0s, tokens: in=412, out=155, total=567
# 65/492 -> Fail -> P@1=False, P@3=False, req=20.3s, tokens: in=664, out=214, total=878
# 66/492 -> Fail -> P@1=False, P@3=True, req=16.0s, tokens: in=477, out=212, total=689
# 67/492 -> Pass -> P@1=True, P@3=True, req=9.7s, tokens: in=370, out=115, total=485
# 68/492 -> Pass -> P@1=True, P@3=True, req=8.7s, tokens: in=316, out=52, total=368
# 69/492 -> Fail -> P@1=False, P@3=False, req=21.0s, tokens: in=668, out=283, total=951
# 70/492 -> Pass -> P@1=True, P@3=True, req=18.2s, tokens: in=507, out=345, total=852
# 71/492 -> Pass -> P@1=True, P@3=True, req=20.2s, tokens: in=608, out=252, total=860
# 72/492 -> Fail -> P@1=False, P@3=True, req=10.5s, tokens: in=286, out=142, total=428
# 73/492 -> Fail -> P@1=False, P@3=False, req=28.1s, tokens: in=728, out=653, total=1381
# 74/492 -> Pass -> P@1=True, P@3=True, req=9.6s, tokens: in=334, out=113, total=447
# 75/492 -> Pass -> P@1=True, P@3=False, req=21.9s, tokens: in=688, out=306, total=994
# 76/492 -> Fail -> P@1=False, P@3=False, req=19.4s, tokens: in=712, out=152, total=864
# 77/492 -> Fail -> P@1=False, P@3=False, req=23.7s, tokens: in=560, out=423, total=983
# 78/492 -> Fail -> P@1=False, P@3=True, req=17.1s, tokens: in=603, out=245, total=848
# 79/492 -> Fail -> P@1=False, P@3=False, req=23.8s, tokens: in=724, out=358, total=1082
# 80/492 -> Fail -> P@1=False, P@3=True, req=9.5s, tokens: in=948, out=84, total=1032
# 81/492 -> Fail -> P@1=False, P@3=False, req=24.2s, tokens: in=728, out=392, total=1120
# 82/492 -> Fail -> P@1=False, P@3=False, req=21.1s, tokens: in=604, out=307, total=911
# 83/492 -> Fail -> P@1=False, P@3=False, req=24.0s, tokens: in=824, out=355, total=1179
# 84/492 -> Fail -> P@1=False, P@3=False, req=19.9s, tokens: in=812, out=139, total=951
# 85/492 -> Pass -> P@1=True, P@3=True, req=11.5s, tokens: in=336, out=113, total=449
# 86/492 -> Fail -> P@1=False, P@3=False, req=19.2s, tokens: in=980, out=180, total=1160
# 87/492 -> Pass -> P@1=True, P@3=True, req=12.3s, tokens: in=350, out=156, total=506
# 88/492 -> Fail -> P@1=False, P@3=False, req=23.8s, tokens: in=620, out=328, total=948
# 89/492 -> Fail -> P@1=False, P@3=False, req=21.3s, tokens: in=688, out=248, total=936
# 90/492 -> Fail -> P@1=False, P@3=False, req=22.2s, tokens: in=616, out=286, total=902
# 91/492 -> Fail -> P@1=False, P@3=False, req=26.2s, tokens: in=716, out=416, total=1132
# 92/492 -> Fail -> P@1=False, P@3=False, req=25.3s, tokens: in=636, out=451, total=1087
# 93/492 -> Fail -> P@1=False, P@3=False, req=29.8s, tokens: in=880, out=578, total=1458
# 94/492 -> Pass -> P@1=True, P@3=True, req=16.9s, tokens: in=501, out=170, total=671
# 95/492 -> Pass -> P@1=True, P@3=True, req=11.4s, tokens: in=438, out=105, total=543
# 96/492 -> Pass -> P@1=True, P@3=True, req=22.5s, tokens: in=716, out=290, total=1006
# 97/492 -> Fail -> P@1=False, P@3=False, req=23.8s, tokens: in=592, out=378, total=970
# 98/492 -> Fail -> P@1=False, P@3=False, req=73.0s, tokens: in=736, out=2742, total=3478
# 99/492 -> Fail -> P@1=False, P@3=False, req=34.1s, tokens: in=692, out=810, total=1502
# 100/492 -> Fail -> P@1=False, P@3=False, req=23.8s, tokens: in=636, out=380, total=1016
# 101/492 -> Fail -> P@1=False, P@3=False, req=26.8s, tokens: in=720, out=546, total=1266
# 102/492 -> Fail -> P@1=False, P@3=False, req=21.9s, tokens: in=700, out=210, total=910
# 103/492 -> Pass -> P@1=True, P@3=True, req=12.7s, tokens: in=298, out=166, total=464
# 104/492 -> Fail -> P@1=False, P@3=False, req=24.1s, tokens: in=696, out=288, total=984
# 105/492 -> Fail -> P@1=False, P@3=False, req=31.0s, tokens: in=672, out=624, total=1296
# 106/492 -> Fail -> P@1=False, P@3=True, req=16.2s, tokens: in=519, out=176, total=695
# 107/492 -> Fail -> P@1=False, P@3=False, req=31.3s, tokens: in=728, out=654, total=1382
# 108/492 -> Fail -> P@1=False, P@3=False, req=23.9s, tokens: in=720, out=325, total=1045
# 109/492 -> Pass -> P@1=True, P@3=True, req=11.5s, tokens: in=338, out=162, total=500
# 110/492 -> Fail -> P@1=False, P@3=False, req=20.5s, tokens: in=656, out=128, total=784
# 111/492 -> Pass -> P@1=True, P@3=True, req=12.3s, tokens: in=302, out=150, total=452
# 112/492 -> Pass -> P@1=True, P@3=True, req=13.8s, tokens: in=278, out=255, total=533
# 113/492 -> Pass -> P@1=True, P@3=True, req=10.5s, tokens: in=338, out=130, total=468
# 114/492 -> Fail -> P@1=False, P@3=False, req=28.9s, tokens: in=616, out=479, total=1095
# 115/492 -> Fail -> P@1=False, P@3=True, req=12.5s, tokens: in=378, out=238, total=616
# 116/492 -> Fail -> P@1=False, P@3=False, req=22.9s, tokens: in=1176, out=271, total=1447
# 117/492 -> Pass -> P@1=True, P@3=True, req=9.8s, tokens: in=414, out=156, total=570
# 118/492 -> Pass -> P@1=True, P@3=False, req=26.4s, tokens: in=592, out=472, total=1064
# 119/492 -> Fail -> P@1=False, P@3=False, req=31.3s, tokens: in=532, out=582, total=1114
# 120/492 -> Fail -> P@1=False, P@3=False, req=24.7s, tokens: in=704, out=353, total=1057
# 121/492 -> Fail -> P@1=False, P@3=False, req=22.7s, tokens: in=792, out=299, total=1091
# 122/492 -> Fail -> P@1=False, P@3=False, req=23.3s, tokens: in=556, out=323, total=879
# 123/492 -> Fail -> P@1=False, P@3=False, req=25.1s, tokens: in=536, out=356, total=892
# 124/492 -> Fail -> P@1=False, P@3=True, req=25.7s, tokens: in=708, out=398, total=1106
# 125/492 -> Pass -> P@1=True, P@3=True, req=10.1s, tokens: in=304, out=110, total=414
# 126/492 -> Pass -> P@1=True, P@3=True, req=13.8s, tokens: in=474, out=153, total=627
# 127/492 -> Fail -> P@1=False, P@3=False, req=25.3s, tokens: in=880, out=448, total=1328
# 128/492 -> Fail -> P@1=False, P@3=False, req=18.2s, tokens: in=588, out=140, total=728
# 129/492 -> Fail -> P@1=False, P@3=False, req=17.6s, tokens: in=696, out=146, total=842
# 130/492 -> Fail -> P@1=False, P@3=True, req=13.4s, tokens: in=495, out=143, total=638
# 131/492 -> Fail -> P@1=False, P@3=False, req=32.7s, tokens: in=620, out=692, total=1312
# 132/492 -> Fail -> P@1=False, P@3=False, req=18.6s, tokens: in=1216, out=269, total=1485
# 133/492 -> Fail -> P@1=False, P@3=True, req=8.7s, tokens: in=350, out=109, total=459
# 134/492 -> Fail -> P@1=False, P@3=False, req=21.8s, tokens: in=812, out=290, total=1102
# 135/492 -> Pass -> P@1=True, P@3=True, req=8.3s, tokens: in=282, out=113, total=395
# 136/492 -> Fail -> P@1=False, P@3=False, req=81.8s, tokens: in=520, out=239, total=759
# 137/492 -> Fail -> P@1=False, P@3=True, req=14.7s, tokens: in=441, out=171, total=612
# 138/492 -> Pass -> P@1=True, P@3=True, req=18.8s, tokens: in=896, out=256, total=1152
# 139/492 -> Fail -> P@1=False, P@3=False, req=28.6s, tokens: in=808, out=650, total=1458
# 140/492 -> Fail -> P@1=False, P@3=False, req=49.6s, tokens: in=708, out=157, total=865
# 141/492 -> Pass -> P@1=True, P@3=True, req=10.3s, tokens: in=316, out=94, total=410
# 142/492 -> Fail -> P@1=False, P@3=False, req=24.8s, tokens: in=732, out=477, total=1209
# 143/492 -> Fail -> P@1=False, P@3=False, req=22.2s, tokens: in=700, out=324, total=1024
# 144/492 -> Fail -> P@1=False, P@3=False, req=19.8s, tokens: in=768, out=191, total=959
# 145/492 -> Pass -> P@1=True, P@3=True, req=12.0s, tokens: in=318, out=150, total=468
# 146/492 -> Fail -> P@1=False, P@3=False, req=22.7s, tokens: in=532, out=419, total=951
# 147/492 -> Pass -> P@1=True, P@3=True, req=10.2s, tokens: in=298, out=132, total=430
# 148/492 -> Fail -> P@1=False, P@3=False, req=19.2s, tokens: in=1512, out=241, total=1753
# 149/492 -> Pass -> P@1=True, P@3=True, req=11.1s, tokens: in=376, out=106, total=482
# 150/492 -> Fail -> P@1=False, P@3=False, req=54.5s, tokens: in=624, out=383, total=1007
# 151/492 -> Pass -> P@1=True, P@3=True, req=16.0s, tokens: in=453, out=145, total=598
# 152/492 -> Fail -> P@1=False, P@3=False, req=20.2s, tokens: in=796, out=162, total=958
# 153/492 -> Fail -> P@1=False, P@3=False, req=51.7s, tokens: in=1416, out=1771, total=3187
# 154/492 -> Fail -> P@1=False, P@3=False, req=25.2s, tokens: in=540, out=360, total=900
# 155/492 -> Fail -> P@1=False, P@3=False, req=25.1s, tokens: in=696, out=382, total=1078
# 156/492 -> Fail -> P@1=False, P@3=False, req=22.2s, tokens: in=696, out=290, total=986
# 157/492 -> Fail -> P@1=False, P@3=False, req=24.8s, tokens: in=760, out=367, total=1127
# 158/492 -> Fail -> P@1=False, P@3=False, req=21.7s, tokens: in=600, out=302, total=902
# 159/492 -> Pass -> P@1=True, P@3=True, req=11.5s, tokens: in=330, out=122, total=452
# 160/492 -> Pass -> P@1=True, P@3=True, req=11.5s, tokens: in=352, out=145, total=497
# 161/492 -> Fail -> P@1=False, P@3=False, req=56.0s, tokens: in=716, out=432, total=1148
# 162/492 -> Pass -> P@1=True, P@3=True, req=12.9s, tokens: in=342, out=181, total=523
# 163/492 -> Fail -> P@1=False, P@3=False, req=28.1s, tokens: in=812, out=674, total=1486
# 164/492 -> Pass -> P@1=True, P@3=True, req=11.4s, tokens: in=318, out=132, total=450
# 165/492 -> Fail -> P@1=False, P@3=False, req=52.9s, tokens: in=588, out=287, total=875
# 166/492 -> Fail -> P@1=False, P@3=False, req=23.4s, tokens: in=940, out=199, total=1139
# 167/492 -> Pass -> P@1=True, P@3=True, req=12.0s, tokens: in=302, out=143, total=445
# 168/492 -> Fail -> P@1=False, P@3=False, req=19.7s, tokens: in=640, out=120, total=760
# 169/492 -> Fail -> P@1=False, P@3=False, req=26.2s, tokens: in=636, out=321, total=957
# 170/492 -> Fail -> P@1=False, P@3=False, req=23.9s, tokens: in=696, out=223, total=919
# 171/492 -> Pass -> P@1=True, P@3=True, req=13.2s, tokens: in=370, out=176, total=546
# 172/492 -> Pass -> P@1=True, P@3=True, req=11.2s, tokens: in=348, out=116, total=464
# 173/492 -> Pass -> P@1=True, P@3=True, req=10.9s, tokens: in=372, out=158, total=530
# 174/492 -> Fail -> P@1=False, P@3=False, req=27.7s, tokens: in=788, out=373, total=1161
# 175/492 -> Fail -> P@1=False, P@3=False, req=23.6s, tokens: in=872, out=300, total=1172
# 176/492 -> Fail -> P@1=False, P@3=False, req=24.7s, tokens: in=696, out=354, total=1050
# 177/492 -> Pass -> P@1=True, P@3=True, req=11.1s, tokens: in=312, out=77, total=389
# 178/492 -> Pass -> P@1=True, P@3=True, req=11.1s, tokens: in=286, out=97, total=383
# 179/492 -> Pass -> P@1=True, P@3=True, req=11.0s, tokens: in=378, out=66, total=444
# 180/492 -> Fail -> P@1=False, P@3=False, req=22.7s, tokens: in=776, out=262, total=1038
# 181/492 -> Fail -> P@1=False, P@3=True, req=26.6s, tokens: in=700, out=461, total=1161
# 182/492 -> Fail -> P@1=False, P@3=False, req=23.9s, tokens: in=688, out=268, total=956
# 183/492 -> Fail -> P@1=False, P@3=False, req=24.4s, tokens: in=784, out=271, total=1055
# 184/492 -> Fail -> P@1=False, P@3=False, req=32.4s, tokens: in=1060, out=547, total=1607
# 185/492 -> Pass -> P@1=True, P@3=True, req=10.7s, tokens: in=298, out=140, total=438
# 186/492 -> Fail -> P@1=False, P@3=False, req=25.4s, tokens: in=832, out=373, total=1205
# 187/492 -> Fail -> P@1=False, P@3=False, req=43.9s, tokens: in=672, out=860, total=1532
# 188/492 -> Fail -> P@1=False, P@3=False, req=25.7s, tokens: in=528, out=365, total=893
# 189/492 -> Pass -> P@1=True, P@3=True, req=13.2s, tokens: in=364, out=128, total=492
# 190/492 -> Fail -> P@1=False, P@3=False, req=43.4s, tokens: in=592, out=1209, total=1801
# 191/492 -> Fail -> P@1=False, P@3=False, req=25.4s, tokens: in=592, out=332, total=924
# 192/492 -> Fail -> P@1=False, P@3=True, req=11.6s, tokens: in=344, out=110, total=454
# 193/492 -> Fail -> P@1=False, P@3=False, req=21.2s, tokens: in=784, out=145, total=929
# 194/492 -> Fail -> P@1=False, P@3=False, req=24.8s, tokens: in=692, out=295, total=987
# 195/492 -> Pass -> P@1=True, P@3=True, req=14.5s, tokens: in=402, out=205, total=607
# 196/492 -> Fail -> P@1=False, P@3=False, req=25.8s, tokens: in=676, out=229, total=905
# 197/492 -> Fail -> P@1=False, P@3=True, req=14.6s, tokens: in=352, out=158, total=510
# 198/492 -> Fail -> P@1=False, P@3=True, req=32.1s, tokens: in=672, out=716, total=1388
# 199/492 -> Pass -> P@1=True, P@3=True, req=13.9s, tokens: in=302, out=116, total=418
# 200/492 -> Fail -> P@1=False, P@3=True, req=22.6s, tokens: in=501, out=243, total=744
# 201/492 -> Pass -> P@1=True, P@3=True, req=21.7s, tokens: in=298, out=166, total=464
# 202/492 -> Fail -> P@1=False, P@3=False, req=26.8s, tokens: in=648, out=219, total=867
# 203/492 -> Fail -> P@1=False, P@3=True, req=23.6s, tokens: in=549, out=233, total=782
# 204/492 -> Fail -> P@1=False, P@3=False, req=30.6s, tokens: in=636, out=333, total=969
# 205/492 -> Fail -> P@1=False, P@3=False, req=34.3s, tokens: in=680, out=506, total=1186
# 206/492 -> Fail -> P@1=False, P@3=False, req=36.4s, tokens: in=844, out=518, total=1362
# 207/492 -> Pass -> P@1=True, P@3=True, req=16.6s, tokens: in=332, out=143, total=475
# 208/492 -> Fail -> P@1=False, P@3=False, req=35.4s, tokens: in=556, out=560, total=1116
# 209/492 -> Fail -> P@1=False, P@3=False, req=47.6s, tokens: in=792, out=1381, total=2173
# 210/492 -> Pass -> P@1=True, P@3=True, req=14.9s, tokens: in=346, out=143, total=489
# 211/492 -> Fail -> P@1=False, P@3=False, req=31.7s, tokens: in=684, out=384, total=1068
# 212/492 -> Fail -> P@1=False, P@3=False, req=30.3s, tokens: in=696, out=129, total=825
# 213/492 -> Fail -> P@1=False, P@3=True, req=17.0s, tokens: in=334, out=229, total=563
# 214/492 -> Pass -> P@1=True, P@3=True, req=12.8s, tokens: in=470, out=179, total=649
# 215/492 -> Pass -> P@1=True, P@3=True, req=24.3s, tokens: in=334, out=249, total=583
# 216/492 -> Pass -> P@1=True, P@3=True, req=21.9s, tokens: in=480, out=173, total=653
# 217/492 -> Fail -> P@1=False, P@3=False, req=31.9s, tokens: in=868, out=487, total=1355
# 218/492 -> Fail -> P@1=False, P@3=False, req=43.5s, tokens: in=664, out=986, total=1650
# 219/492 -> Pass -> P@1=True, P@3=True, req=19.3s, tokens: in=352, out=116, total=468
# 220/492 -> Fail -> P@1=False, P@3=False, req=29.6s, tokens: in=712, out=307, total=1019
# 221/492 -> Fail -> P@1=False, P@3=True, req=23.7s, tokens: in=495, out=241, total=736
# 222/492 -> Fail -> P@1=False, P@3=False, req=26.9s, tokens: in=708, out=154, total=862
# 223/492 -> Fail -> P@1=False, P@3=False, req=44.1s, tokens: in=776, out=541, total=1317
# 224/492 -> Pass -> P@1=True, P@3=True, req=9.3s, tokens: in=290, out=88, total=378
# 225/492 -> Fail -> P@1=False, P@3=False, req=28.7s, tokens: in=700, out=293, total=993
# 226/492 -> Fail -> P@1=False, P@3=True, req=11.8s, tokens: in=324, out=183, total=507
# 227/492 -> Pass -> P@1=True, P@3=True, req=10.3s, tokens: in=296, out=76, total=372
# 228/492 -> Pass -> P@1=True, P@3=True, req=12.3s, tokens: in=296, out=178, total=474
# 229/492 -> Fail -> P@1=False, P@3=True, req=10.4s, tokens: in=414, out=140, total=554
# 230/492 -> Pass -> P@1=True, P@3=True, req=9.7s, tokens: in=284, out=110, total=394
# 231/492 -> Pass -> P@1=True, P@3=True, req=12.6s, tokens: in=380, out=208, total=588
# 232/492 -> Fail -> P@1=False, P@3=False, req=26.8s, tokens: in=992, out=349, total=1341
# 233/492 -> Fail -> P@1=False, P@3=False, req=18.3s, tokens: in=596, out=56, total=652
# 234/492 -> Pass -> P@1=True, P@3=True, req=11.1s, tokens: in=370, out=176, total=546
# 235/492 -> Fail -> P@1=False, P@3=True, req=9.6s, tokens: in=366, out=159, total=525
# 236/492 -> Fail -> P@1=False, P@3=False, req=24.1s, tokens: in=568, out=338, total=906
# 237/492 -> Fail -> P@1=False, P@3=False, req=30.1s, tokens: in=1032, out=429, total=1461
# 238/492 -> Fail -> P@1=False, P@3=False, req=22.5s, tokens: in=644, out=273, total=917
# 239/492 -> Fail -> P@1=False, P@3=False, req=20.0s, tokens: in=616, out=236, total=852
# 240/492 -> Pass -> P@1=True, P@3=True, req=11.2s, tokens: in=312, out=166, total=478
# 241/492 -> Pass -> P@1=True, P@3=True, req=9.3s, tokens: in=320, out=90, total=410
# 242/492 -> Pass -> P@1=True, P@3=True, req=11.1s, tokens: in=310, out=112, total=422
# 243/492 -> Fail -> P@1=False, P@3=False, req=48.7s, tokens: in=784, out=911, total=1695
# 244/492 -> Fail -> P@1=False, P@3=False, req=23.7s, tokens: in=576, out=337, total=913
# 245/492 -> Fail -> P@1=False, P@3=False, req=24.4s, tokens: in=740, out=325, total=1065
# 246/492 -> Fail -> P@1=False, P@3=False, req=23.5s, tokens: in=632, out=281, total=913
# 247/492 -> Pass -> P@1=True, P@3=True, req=10.9s, tokens: in=326, out=86, total=412
# 248/492 -> Fail -> P@1=False, P@3=False, req=21.7s, tokens: in=632, out=254, total=886
# 249/492 -> Fail -> P@1=False, P@3=False, req=36.0s, tokens: in=688, out=899, total=1587
# 250/492 -> Fail -> P@1=False, P@3=False, req=23.7s, tokens: in=588, out=271, total=859
# 251/492 -> Fail -> P@1=False, P@3=False, req=25.3s, tokens: in=532, out=444, total=976
# 252/492 -> Fail -> P@1=False, P@3=False, req=22.5s, tokens: in=876, out=403, total=1279
# 253/492 -> Fail -> P@1=False, P@3=False, req=32.7s, tokens: in=584, out=366, total=950
# 254/492 -> Fail -> P@1=False, P@3=False, req=26.3s, tokens: in=568, out=426, total=994
# 255/492 -> Fail -> P@1=False, P@3=True, req=16.0s, tokens: in=483, out=169, total=652
# 256/492 -> Fail -> P@1=False, P@3=True, req=10.4s, tokens: in=346, out=110, total=456
# 257/492 -> Fail -> P@1=False, P@3=False, req=21.6s, tokens: in=612, out=247, total=859
# 258/492 -> Fail -> P@1=False, P@3=False, req=24.4s, tokens: in=544, out=389, total=933
# 259/492 -> Fail -> P@1=False, P@3=False, req=22.4s, tokens: in=684, out=192, total=876
# 260/492 -> Fail -> P@1=False, P@3=False, req=22.8s, tokens: in=532, out=327, total=859
# 261/492 -> Fail -> P@1=False, P@3=True, req=16.4s, tokens: in=561, out=151, total=712
# 262/492 -> Fail -> P@1=False, P@3=False, req=19.8s, tokens: in=532, out=128, total=660
# 263/492 -> Fail -> P@1=False, P@3=False, req=25.3s, tokens: in=792, out=398, total=1190
# 264/492 -> Fail -> P@1=False, P@3=True, req=25.4s, tokens: in=780, out=305, total=1085
# 265/492 -> Fail -> P@1=False, P@3=True, req=23.5s, tokens: in=657, out=379, total=1036
# 266/492 -> Fail -> P@1=False, P@3=False, req=29.5s, tokens: in=668, out=432, total=1100
# 267/492 -> Fail -> P@1=False, P@3=False, req=25.9s, tokens: in=620, out=354, total=974
# 268/492 -> Pass -> P@1=True, P@3=True, req=13.3s, tokens: in=314, out=224, total=538
# 269/492 -> Fail -> P@1=False, P@3=False, req=27.5s, tokens: in=680, out=408, total=1088
# 270/492 -> Fail -> P@1=False, P@3=False, req=29.8s, tokens: in=832, out=490, total=1322
# 271/492 -> Fail -> P@1=False, P@3=False, req=17.5s, tokens: in=624, out=80, total=704
# 272/492 -> Pass -> P@1=True, P@3=True, req=8.6s, tokens: in=314, out=56, total=370
# 273/492 -> Pass -> P@1=True, P@3=True, req=15.5s, tokens: in=501, out=198, total=699
# 274/492 -> Pass -> P@1=True, P@3=True, req=13.1s, tokens: in=537, out=89, total=626
# 275/492 -> Pass -> P@1=True, P@3=True, req=8.7s, tokens: in=324, out=76, total=400
# 276/492 -> Fail -> P@1=False, P@3=False, req=25.5s, tokens: in=692, out=468, total=1160
# 277/492 -> Fail -> P@1=False, P@3=False, req=29.5s, tokens: in=1056, out=551, total=1607
# 278/492 -> Fail -> P@1=False, P@3=False, req=23.8s, tokens: in=784, out=364, total=1148
# 279/492 -> Fail -> P@1=False, P@3=False, req=22.2s, tokens: in=648, out=234, total=882
# 280/492 -> Fail -> P@1=False, P@3=True, req=12.1s, tokens: in=304, out=170, total=474
# 281/492 -> Fail -> P@1=False, P@3=False, req=24.1s, tokens: in=1272, out=395, total=1667
# 282/492 -> Fail -> P@1=False, P@3=False, req=20.6s, tokens: in=712, out=274, total=986
# 283/492 -> Fail -> P@1=False, P@3=False, req=76.1s, tokens: in=912, out=498, total=1410
# 284/492 -> Pass -> P@1=True, P@3=False, req=20.4s, tokens: in=936, out=210, total=1146
# 285/492 -> Pass -> P@1=True, P@3=True, req=9.3s, tokens: in=316, out=94, total=410
# 286/492 -> Pass -> P@1=True, P@3=True, req=18.7s, tokens: in=453, out=315, total=768
# 287/492 -> Fail -> P@1=False, P@3=True, req=10.1s, tokens: in=376, out=135, total=511
# 288/492 -> Pass -> P@1=True, P@3=True, req=9.2s, tokens: in=296, out=129, total=425
# 289/492 -> Fail -> P@1=False, P@3=False, req=16.7s, tokens: in=660, out=128, total=788
# 290/492 -> Fail -> P@1=False, P@3=False, req=21.7s, tokens: in=592, out=321, total=913
# 291/492 -> Pass -> P@1=True, P@3=True, req=28.1s, tokens: in=633, out=618, total=1251
# 292/492 -> Fail -> P@1=False, P@3=True, req=21.9s, tokens: in=596, out=247, total=843
# 293/492 -> Fail -> P@1=False, P@3=False, req=16.8s, tokens: in=788, out=122, total=910
# 294/492 -> Pass -> P@1=True, P@3=True, req=8.5s, tokens: in=310, out=144, total=454
# 295/492 -> Fail -> P@1=False, P@3=False, req=21.8s, tokens: in=640, out=312, total=952
# 296/492 -> Fail -> P@1=False, P@3=False, req=21.2s, tokens: in=688, out=327, total=1015
# 297/492 -> Pass -> P@1=True, P@3=True, req=15.0s, tokens: in=627, out=192, total=819
# 298/492 -> Fail -> P@1=False, P@3=False, req=18.5s, tokens: in=772, out=198, total=970
# 299/492 -> Fail -> P@1=False, P@3=True, req=16.4s, tokens: in=543, out=223, total=766
# 300/492 -> Fail -> P@1=False, P@3=False, req=23.3s, tokens: in=1128, out=383, total=1511
# 301/492 -> Fail -> P@1=False, P@3=False, req=15.8s, tokens: in=656, out=119, total=775
# 302/492 -> Pass -> P@1=True, P@3=True, req=10.5s, tokens: in=270, out=184, total=454
# 303/492 -> Fail -> P@1=False, P@3=False, req=19.3s, tokens: in=636, out=181, total=817
# 304/492 -> Fail -> P@1=False, P@3=False, req=20.6s, tokens: in=756, out=313, total=1069
# 305/492 -> Fail -> P@1=False, P@3=True, req=10.5s, tokens: in=300, out=191, total=491
# 306/492 -> Fail -> P@1=False, P@3=False, req=14.1s, tokens: in=552, out=62, total=614
# 307/492 -> Pass -> P@1=True, P@3=True, req=8.8s, tokens: in=340, out=84, total=424
# 308/492 -> Fail -> P@1=False, P@3=False, req=19.8s, tokens: in=540, out=374, total=914
# 309/492 -> Pass -> P@1=True, P@3=True, req=15.3s, tokens: in=534, out=215, total=749
# 310/492 -> Pass -> P@1=True, P@3=True, req=10.2s, tokens: in=302, out=118, total=420
# 311/492 -> Pass -> P@1=True, P@3=True, req=13.7s, tokens: in=318, out=237, total=555
# 312/492 -> Fail -> P@1=False, P@3=False, req=21.1s, tokens: in=644, out=314, total=958
# 313/492 -> Fail -> P@1=False, P@3=False, req=98.4s, tokens: in=664, out=2194, total=2858
# 314/492 -> Fail -> P@1=False, P@3=False, req=20.6s, tokens: in=560, out=251, total=811
# 315/492 -> Fail -> P@1=False, P@3=False, req=17.0s, tokens: in=588, out=156, total=744
# 316/492 -> Fail -> P@1=False, P@3=False, req=16.7s, tokens: in=592, out=108, total=700
# 317/492 -> Fail -> P@1=False, P@3=False, req=19.9s, tokens: in=592, out=282, total=874
# 318/492 -> Fail -> P@1=False, P@3=True, req=13.7s, tokens: in=411, out=128, total=539
# 319/492 -> Fail -> P@1=False, P@3=False, req=17.6s, tokens: in=556, out=154, total=710
# 320/492 -> Fail -> P@1=False, P@3=False, req=17.6s, tokens: in=632, out=180, total=812
# 321/492 -> Pass -> P@1=True, P@3=True, req=10.9s, tokens: in=306, out=177, total=483
# 322/492 -> Fail -> P@1=False, P@3=False, req=18.3s, tokens: in=620, out=218, total=838
# 323/492 -> Fail -> P@1=False, P@3=False, req=19.7s, tokens: in=736, out=246, total=982
# 324/492 -> Pass -> P@1=True, P@3=True, req=10.3s, tokens: in=296, out=110, total=406
# 325/492 -> Fail -> P@1=False, P@3=False, req=22.0s, tokens: in=636, out=355, total=991
# 326/492 -> Fail -> P@1=False, P@3=False, req=21.6s, tokens: in=544, out=439, total=983
# 327/492 -> Pass -> P@1=True, P@3=True, req=8.2s, tokens: in=330, out=88, total=418
# 328/492 -> Pass -> P@1=True, P@3=True, req=8.7s, tokens: in=308, out=150, total=458
# 329/492 -> Fail -> P@1=False, P@3=False, req=18.7s, tokens: in=632, out=176, total=808
# 330/492 -> Fail -> P@1=False, P@3=False, req=19.4s, tokens: in=716, out=230, total=946
# 331/492 -> Fail -> P@1=False, P@3=True, req=13.4s, tokens: in=504, out=161, total=665
# 332/492 -> Fail -> P@1=False, P@3=True, req=44.2s, tokens: in=340, out=251, total=591
# 333/492 -> Fail -> P@1=False, P@3=False, req=17.5s, tokens: in=788, out=137, total=925
# 334/492 -> Fail -> P@1=False, P@3=False, req=19.9s, tokens: in=584, out=198, total=782
# 335/492 -> Pass -> P@1=True, P@3=True, req=13.3s, tokens: in=458, out=229, total=687
# 336/492 -> Fail -> P@1=False, P@3=False, req=21.1s, tokens: in=700, out=344, total=1044
# 337/492 -> Pass -> P@1=True, P@3=True, req=10.2s, tokens: in=320, out=110, total=430
# 338/492 -> Fail -> P@1=False, P@3=True, req=16.8s, tokens: in=568, out=186, total=754
# 339/492 -> Pass -> P@1=True, P@3=True, req=9.5s, tokens: in=310, out=138, total=448
# 340/492 -> Pass -> P@1=True, P@3=True, req=9.4s, tokens: in=338, out=92, total=430
# 341/492 -> Fail -> P@1=False, P@3=True, req=13.9s, tokens: in=576, out=124, total=700
# 342/492 -> Fail -> P@1=False, P@3=False, req=26.7s, tokens: in=600, out=431, total=1031
# 343/492 -> Fail -> P@1=False, P@3=False, req=33.2s, tokens: in=624, out=805, total=1429
# 344/492 -> Pass -> P@1=True, P@3=False, req=21.4s, tokens: in=660, out=353, total=1013
# 345/492 -> Fail -> P@1=False, P@3=False, req=20.9s, tokens: in=628, out=256, total=884
# 346/492 -> Fail -> P@1=False, P@3=False, req=24.2s, tokens: in=620, out=365, total=985
# 347/492 -> Fail -> P@1=False, P@3=False, req=19.8s, tokens: in=600, out=174, total=774
# 348/492 -> Fail -> P@1=False, P@3=False, req=22.3s, tokens: in=544, out=268, total=812
# 349/492 -> Fail -> P@1=False, P@3=True, req=10.4s, tokens: in=278, out=64, total=342
# 350/492 -> Fail -> P@1=False, P@3=False, req=23.0s, tokens: in=776, out=296, total=1072
# 351/492 -> Pass -> P@1=True, P@3=True, req=12.5s, tokens: in=314, out=164, total=478
# 352/492 -> Fail -> P@1=False, P@3=False, req=34.1s, tokens: in=820, out=600, total=1420
# 353/492 -> Fail -> P@1=False, P@3=False, req=22.4s, tokens: in=1084, out=286, total=1370
# 354/492 -> Fail -> P@1=False, P@3=True, req=29.7s, tokens: in=544, out=545, total=1089
# 355/492 -> Fail -> P@1=False, P@3=False, req=120.7s, tokens: in=816, out=531, total=1347
# 356/492 -> Pass -> P@1=True, P@3=True, req=14.9s, tokens: in=342, out=181, total=523
# 357/492 -> Fail -> P@1=False, P@3=False, req=21.0s, tokens: in=632, out=158, total=790
# 358/492 -> Fail -> P@1=False, P@3=True, req=17.4s, tokens: in=528, out=173, total=701
# 359/492 -> Fail -> P@1=False, P@3=False, req=25.0s, tokens: in=680, out=318, total=998
# 360/492 -> Fail -> P@1=False, P@3=False, req=24.5s, tokens: in=856, out=258, total=1114
# 361/492 -> Fail -> P@1=False, P@3=True, req=11.5s, tokens: in=286, out=97, total=383
# 362/492 -> Fail -> P@1=False, P@3=False, req=26.5s, tokens: in=680, out=389, total=1069
# 363/492 -> Pass -> P@1=True, P@3=True, req=11.7s, tokens: in=304, out=66, total=370
# 364/492 -> Fail -> P@1=False, P@3=True, req=29.5s, tokens: in=668, out=550, total=1218
# 365/492 -> Fail -> P@1=False, P@3=False, req=27.4s, tokens: in=740, out=444, total=1184
# 366/492 -> Fail -> P@1=False, P@3=False, req=54.8s, tokens: in=656, out=290, total=946
# 367/492 -> Fail -> P@1=False, P@3=False, req=25.3s, tokens: in=672, out=203, total=875
# 368/492 -> Fail -> P@1=False, P@3=True, req=14.0s, tokens: in=320, out=129, total=449
# 369/492 -> Fail -> P@1=False, P@3=False, req=22.2s, tokens: in=656, out=196, total=852
# 370/492 -> Fail -> P@1=False, P@3=False, req=31.5s, tokens: in=812, out=482, total=1294
# 371/492 -> Pass -> P@1=True, P@3=True, req=13.3s, tokens: in=320, out=160, total=480
# 372/492 -> Fail -> P@1=False, P@3=False, req=29.7s, tokens: in=672, out=473, total=1145
# 373/492 -> Fail -> P@1=False, P@3=False, req=42.7s, tokens: in=696, out=1219, total=1915
# 374/492 -> Fail -> P@1=False, P@3=False, req=25.6s, tokens: in=760, out=229, total=989
# 375/492 -> Fail -> P@1=False, P@3=False, req=23.4s, tokens: in=636, out=179, total=815
# 376/492 -> Fail -> P@1=False, P@3=False, req=28.0s, tokens: in=696, out=424, total=1120
# 377/492 -> Fail -> P@1=False, P@3=False, req=29.5s, tokens: in=672, out=512, total=1184
# 378/492 -> Fail -> P@1=False, P@3=False, req=28.4s, tokens: in=760, out=388, total=1148
# 379/492 -> Fail -> P@1=False, P@3=False, req=38.0s, tokens: in=536, out=672, total=1208
# 380/492 -> Pass -> P@1=True, P@3=True, req=27.2s, tokens: in=636, out=196, total=832
# 381/492 -> Fail -> P@1=False, P@3=False, req=43.8s, tokens: in=1044, out=1031, total=2075
# 382/492 -> Fail -> P@1=False, P@3=False, req=32.5s, tokens: in=700, out=491, total=1191
# 383/492 -> Pass -> P@1=True, P@3=True, req=12.3s, tokens: in=370, out=92, total=462
# 384/492 -> Fail -> P@1=False, P@3=False, req=27.4s, tokens: in=724, out=222, total=946
# 385/492 -> Fail -> P@1=False, P@3=False, req=39.2s, tokens: in=860, out=849, total=1709
# 386/492 -> Fail -> P@1=False, P@3=True, req=16.1s, tokens: in=378, out=212, total=590
# 387/492 -> Fail -> P@1=False, P@3=False, req=26.1s, tokens: in=668, out=249, total=917
# 388/492 -> Fail -> P@1=False, P@3=False, req=25.8s, tokens: in=616, out=246, total=862
# 389/492 -> Fail -> P@1=False, P@3=False, req=34.0s, tokens: in=728, out=647, total=1375
# 390/492 -> Fail -> P@1=False, P@3=False, req=34.5s, tokens: in=724, out=613, total=1337
# 391/492 -> Fail -> P@1=False, P@3=False, req=22.4s, tokens: in=712, out=72, total=784
# 392/492 -> Fail -> P@1=False, P@3=False, req=25.3s, tokens: in=696, out=270, total=966
# 393/492 -> Pass -> P@1=True, P@3=True, req=22.9s, tokens: in=498, out=270, total=768
# 394/492 -> Fail -> P@1=False, P@3=True, req=10.1s, tokens: in=264, out=49, total=313
# 395/492 -> Fail -> P@1=False, P@3=False, req=48.0s, tokens: in=648, out=1321, total=1969
# 396/492 -> Fail -> P@1=False, P@3=False, req=26.5s, tokens: in=668, out=283, total=951
# 397/492 -> Fail -> P@1=False, P@3=False, req=24.5s, tokens: in=564, out=266, total=830
# 398/492 -> Fail -> P@1=False, P@3=False, req=33.1s, tokens: in=1296, out=637, total=1933
# 399/492 -> Pass -> P@1=True, P@3=True, req=15.5s, tokens: in=298, out=206, total=504
# 400/492 -> Fail -> P@1=False, P@3=False, req=28.1s, tokens: in=872, out=364, total=1236
# 401/492 -> Fail -> P@1=False, P@3=False, req=24.1s, tokens: in=808, out=255, total=1063
# 402/492 -> Pass -> P@1=True, P@3=True, req=11.4s, tokens: in=326, out=72, total=398
# 403/492 -> Pass -> P@1=True, P@3=True, req=11.9s, tokens: in=332, out=96, total=428
# 404/492 -> Fail -> P@1=False, P@3=False, req=26.2s, tokens: in=820, out=289, total=1109
# 405/492 -> Pass -> P@1=True, P@3=True, req=12.7s, tokens: in=310, out=116, total=426
# 406/492 -> Fail -> P@1=False, P@3=False, req=27.8s, tokens: in=588, out=303, total=891
# 407/492 -> Fail -> P@1=False, P@3=False, req=27.2s, tokens: in=600, out=312, total=912
# 408/492 -> Pass -> P@1=True, P@3=True, req=11.5s, tokens: in=396, out=154, total=550
# 409/492 -> Pass -> P@1=True, P@3=True, req=11.1s, tokens: in=332, out=108, total=440
# 410/492 -> Fail -> P@1=False, P@3=False, req=118.7s, tokens: in=772, out=509, total=1281
# 411/492 -> Fail -> P@1=False, P@3=False, req=24.2s, tokens: in=616, out=220, total=836
# 412/492 -> Fail -> P@1=False, P@3=False, req=27.1s, tokens: in=696, out=315, total=1011
# 413/492 -> Fail -> P@1=False, P@3=False, req=24.9s, tokens: in=604, out=264, total=868
# 414/492 -> Fail -> P@1=False, P@3=True, req=32.0s, tokens: in=688, out=448, total=1136
# 415/492 -> Fail -> P@1=False, P@3=False, req=23.6s, tokens: in=668, out=208, total=876
# 416/492 -> Fail -> P@1=False, P@3=True, req=12.3s, tokens: in=300, out=132, total=432
# 417/492 -> Pass -> P@1=True, P@3=True, req=13.1s, tokens: in=312, out=144, total=456
# 418/492 -> Fail -> P@1=False, P@3=False, req=23.0s, tokens: in=648, out=186, total=834
# 419/492 -> Fail -> P@1=False, P@3=True, req=18.1s, tokens: in=513, out=175, total=688
# 420/492 -> Fail -> P@1=False, P@3=False, req=27.5s, tokens: in=848, out=351, total=1199
# 421/492 -> Pass -> P@1=True, P@3=True, req=20.7s, tokens: in=462, out=249, total=711
# 422/492 -> Fail -> P@1=False, P@3=False, req=28.2s, tokens: in=600, out=261, total=861
# 423/492 -> Pass -> P@1=True, P@3=True, req=13.5s, tokens: in=328, out=108, total=436
# 424/492 -> Fail -> P@1=False, P@3=True, req=18.0s, tokens: in=292, out=255, total=547
# 425/492 -> Fail -> P@1=False, P@3=False, req=54.1s, tokens: in=1004, out=1569, total=2573
# 426/492 -> Pass -> P@1=True, P@3=True, req=24.4s, tokens: in=567, out=322, total=889
# 427/492 -> Pass -> P@1=True, P@3=True, req=13.2s, tokens: in=328, out=120, total=448
# 428/492 -> Pass -> P@1=True, P@3=True, req=13.6s, tokens: in=286, out=78, total=364
# 429/492 -> Fail -> P@1=False, P@3=False, req=29.4s, tokens: in=696, out=399, total=1095
# 430/492 -> Fail -> P@1=False, P@3=False, req=29.1s, tokens: in=876, out=415, total=1291
# 431/492 -> Pass -> P@1=True, P@3=True, req=14.4s, tokens: in=380, out=155, total=535
# 432/492 -> Fail -> P@1=False, P@3=False, req=24.5s, tokens: in=612, out=152, total=764
# 433/492 -> Pass -> P@1=True, P@3=True, req=13.9s, tokens: in=362, out=125, total=487
# 434/492 -> Fail -> P@1=False, P@3=False, req=26.4s, tokens: in=1236, out=239, total=1475
# 435/492 -> Fail -> P@1=False, P@3=False, req=31.7s, tokens: in=788, out=561, total=1349
# 436/492 -> Pass -> P@1=True, P@3=True, req=14.6s, tokens: in=332, out=132, total=464
# 437/492 -> Fail -> P@1=False, P@3=False, req=28.7s, tokens: in=808, out=445, total=1253
# 438/492 -> Pass -> P@1=True, P@3=True, req=17.3s, tokens: in=364, out=338, total=702
# 439/492 -> Fail -> P@1=False, P@3=False, req=22.9s, tokens: in=632, out=121, total=753
# 440/492 -> Fail -> P@1=False, P@3=False, req=28.0s, tokens: in=668, out=383, total=1051
# 441/492 -> Pass -> P@1=True, P@3=True, req=13.5s, tokens: in=362, out=130, total=492
# 442/492 -> Pass -> P@1=True, P@3=True, req=25.4s, tokens: in=531, out=278, total=809
# 443/492 -> Fail -> P@1=False, P@3=False, req=28.0s, tokens: in=516, out=283, total=799
# 444/492 -> Pass -> P@1=True, P@3=True, req=13.8s, tokens: in=388, out=213, total=601
# 445/492 -> Fail -> P@1=False, P@3=False, req=39.3s, tokens: in=604, out=920, total=1524
# 446/492 -> Fail -> P@1=False, P@3=False, req=43.4s, tokens: in=652, out=1183, total=1835
# 447/492 -> Fail -> P@1=False, P@3=False, req=31.0s, tokens: in=820, out=385, total=1205
# 448/492 -> Fail -> P@1=False, P@3=False, req=28.0s, tokens: in=764, out=389, total=1153
# 449/492 -> Fail -> P@1=False, P@3=False, req=23.2s, tokens: in=752, out=104, total=856
# 450/492 -> Fail -> P@1=False, P@3=False, req=56.7s, tokens: in=1448, out=1490, total=2938
# 451/492 -> Fail -> P@1=False, P@3=False, req=23.0s, tokens: in=572, out=163, total=735
# 452/492 -> Fail -> P@1=False, P@3=True, req=20.1s, tokens: in=588, out=203, total=791
# 453/492 -> Fail -> P@1=False, P@3=False, req=27.9s, tokens: in=552, out=271, total=823
# 454/492 -> Pass -> P@1=True, P@3=True, req=12.4s, tokens: in=322, out=98, total=420
# 455/492 -> Fail -> P@1=False, P@3=True, req=20.6s, tokens: in=591, out=234, total=825
# 456/492 -> Fail -> P@1=False, P@3=False, req=26.3s, tokens: in=1052, out=317, total=1369
# 457/492 -> Pass -> P@1=True, P@3=True, req=21.5s, tokens: in=302, out=337, total=639
# 458/492 -> Fail -> P@1=False, P@3=False, req=26.4s, tokens: in=776, out=382, total=1158
# 459/492 -> Pass -> P@1=True, P@3=True, req=11.7s, tokens: in=402, out=76, total=478
# 460/492 -> Fail -> P@1=False, P@3=True, req=12.4s, tokens: in=308, out=120, total=428
# 461/492 -> Fail -> P@1=False, P@3=False, req=21.5s, tokens: in=848, out=200, total=1048
# 462/492 -> Pass -> P@1=True, P@3=True, req=12.9s, tokens: in=338, out=130, total=468
# 463/492 -> Pass -> P@1=True, P@3=True, req=18.8s, tokens: in=474, out=209, total=683
# 464/492 -> Fail -> P@1=False, P@3=False, req=30.5s, tokens: in=796, out=490, total=1286
# 465/492 -> Fail -> P@1=False, P@3=False, req=29.3s, tokens: in=640, out=510, total=1150
# 466/492 -> Fail -> P@1=False, P@3=False, req=30.0s, tokens: in=784, out=406, total=1190
# 467/492 -> Fail -> P@1=False, P@3=True, req=25.0s, tokens: in=584, out=286, total=870
# 468/492 -> Fail -> P@1=False, P@3=False, req=31.6s, tokens: in=740, out=530, total=1270
# 469/492 -> Fail -> P@1=False, P@3=True, req=21.5s, tokens: in=471, out=367, total=838
# 470/492 -> Fail -> P@1=False, P@3=True, req=19.5s, tokens: in=525, out=272, total=797
# 471/492 -> Fail -> P@1=False, P@3=False, req=32.0s, tokens: in=816, out=506, total=1322
# 472/492 -> Fail -> P@1=False, P@3=True, req=11.9s, tokens: in=344, out=147, total=491
# 473/492 -> Pass -> P@1=True, P@3=True, req=13.4s, tokens: in=318, out=208, total=526
# 474/492 -> Fail -> P@1=False, P@3=False, req=17.1s, tokens: in=640, out=252, total=892
# 475/492 -> Fail -> P@1=False, P@3=True, req=14.4s, tokens: in=414, out=186, total=600
# 476/492 -> Fail -> P@1=False, P@3=False, req=20.1s, tokens: in=776, out=461, total=1237
# 477/492 -> Fail -> P@1=False, P@3=False, req=23.1s, tokens: in=640, out=338, total=978
# 478/492 -> Fail -> P@1=False, P@3=False, req=19.0s, tokens: in=672, out=323, total=995
# 479/492 -> Fail -> P@1=False, P@3=False, req=14.9s, tokens: in=1008, out=302, total=1310
# 480/492 -> Fail -> P@1=False, P@3=False, req=13.8s, tokens: in=612, out=270, total=882
# 481/492 -> Fail -> P@1=False, P@3=False, req=15.8s, tokens: in=800, out=344, total=1144
# 482/492 -> Fail -> P@1=False, P@3=False, req=17.2s, tokens: in=716, out=400, total=1116
# 483/492 -> Fail -> P@1=False, P@3=False, req=18.8s, tokens: in=800, out=459, total=1259
# 484/492 -> Fail -> P@1=False, P@3=False, req=42.9s, tokens: in=652, out=206, total=858
# 485/492 -> Fail -> P@1=False, P@3=False, req=58.7s, tokens: in=676, out=370, total=1046
# 486/492 -> Fail -> P@1=False, P@3=True, req=56.9s, tokens: in=808, out=2070, total=2878
# 487/492 -> Fail -> P@1=False, P@3=False, req=34.7s, tokens: in=708, out=1171, total=1879
# 488/492 -> Fail -> P@1=False, P@3=False, req=82.6s, tokens: in=688, out=150, total=838
# 489/492 -> Fail -> P@1=False, P@3=False, req=100.9s, tokens: in=692, out=2337, total=3029
# 490/492 -> Fail -> P@1=False, P@3=False, req=78.2s, tokens: in=804, out=462, total=1266
# 491/492 -> Fail -> P@1=False, P@3=False, req=101.2s, tokens: in=552, out=299, total=851
# 492/492 -> Fail -> P@1=False, P@3=False, req=99.1s, tokens: in=636, out=424, total=1060
#
# Total tokens: in=292227, out=156732, total=448959
#
# Completed in 448.0s (0.91s per problem)

# %% [markdown]
# ## Compute Metrics

# %%
results_df = pd.DataFrame(results)
N = len(results_df)

pass_at_1 = results_df['pass@1'].sum() / N
pass_at_3 = results_df['pass@3'].sum() / N
greedy_exec_rate = results_df['exec_ok_greedy'].sum() / N
sampled_exec_rate = sum([results_df[f'exec_ok_{j}'].sum() for j in range(1, N_SAMPLES+1)]) / (N * N_SAMPLES)

# New metrics
exec_ok_rate = results_df['exec_ok_greedy'].sum() / N  # Fraction where 1st greedy gen executes without errors
exec_ok_cases = results_df[results_df['exec_ok_greedy'] == True]
correct_given_exec = exec_ok_cases['correct_greedy'].sum() / len(exec_ok_cases) if len(exec_ok_cases) > 0 else 0.0

passed = results_df[results_df['pass@3'] == True]
mean_first_success = passed['first_success_attempt'].mean() if len(passed) > 0 else None

summary = {
    'model': MODEL_NAME,
    'dataset': DATASET_NAME,
    'n_problems': N,
    'pass@1': pass_at_1,
    'pass@3': pass_at_3,
    'greedy_exec_rate': greedy_exec_rate,
    'sampled_exec_rate': sampled_exec_rate,
    'exec_ok_rate': exec_ok_rate,
    'correct_given_exec': correct_given_exec,
    'mean_first_success_attempt': mean_first_success,
    'timestamp': datetime.now().isoformat()
}

print("\n" + "="*60)
print("EVALUATION SUMMARY")
print("="*60)
print(f"Model: {summary['model']}")
print(f"Dataset: {summary['dataset']}")
print(f"Problems: {summary['n_problems']}")
print()
print(f"Verified Pass@1:     {summary['pass@1']:.2%}")
print(f"Verified Pass@3:     {summary['pass@3']:.2%}")
print()
print(f"Greedy exec rate:    {summary['greedy_exec_rate']:.2%}")
print(f"Sampled exec rate:   {summary['sampled_exec_rate']:.2%}")
print()
print(f"Exec OK rate:        {summary['exec_ok_rate']:.2%}  (1st greedy gen)")
print(f"Correct given exec:  {summary['correct_given_exec']:.2%}  (P(correct | exec_ok))")
if summary['mean_first_success_attempt']:
    print(f"Mean first success:  {summary['mean_first_success_attempt']:.2f}")
print("="*60)
# Out:
# ============================================================
# EVALUATION SUMMARY
# ============================================================
# Model: qwen
# Dataset: gemma_balanced
# Problems: 492
#
# Verified Pass@1:     28.86%
# Verified Pass@3:     41.26%
#
# Greedy exec rate:    79.88%
# Sampled exec rate:   58.13%
#
# Exec OK rate:        79.88%  (1st greedy gen)
# Correct given exec:  36.13%  (P(correct | exec_ok))
# Mean first success:  1.36
# ============================================================

# %%
============================================================
EVALUATION SUMMARY
============================================================
Model: qwen
Dataset: gemma_balanced
Problems: 492

Verified Pass@1:     28.86%
Verified Pass@3:     41.26%

Greedy exec rate:    79.88%
Sampled exec rate:   58.13%

Exec OK rate:        79.88%  (1st greedy gen)
Correct given exec:  36.13%  (P(correct | exec_ok))
Mean first success:  1.36
============================================================

# %% [markdown]
# ## Per-Domain & Per-Level Breakdown

# %%
def _build_breakdown(df, group_col, label):
    """Build a pass/fail breakdown table grouped by group_col."""
    # Compute pass@2 (any of first 2 samples correct)
    df = df.copy()
    df['pass@2'] = df.apply(
        lambda r: any(r.get(f'correct_{j}', False) for j in range(1, min(3, N_SAMPLES + 1))), axis=1
    )

    rows = []
    for name, grp in df.groupby(group_col, sort=True):
        n = len(grp)
        p1 = grp['pass@1'].sum()
        p2 = grp['pass@2'].sum()
        p3 = grp['pass@3'].sum()
        rows.append({
            label: name,
            'N': n,
            'Pass@1': int(p1),
            'Pass@1%': f'{p1/n:.1%}',
            'Fail@1': int(n - p1),
            'Pass@2': int(p2),
            'Pass@2%': f'{p2/n:.1%}',
            'Fail@2': int(n - p2),
            'Pass@3': int(p3),
            'Pass@3%': f'{p3/n:.1%}',
            'Fail@3': int(n - p3),
            'Greedy Pass': int(grp['correct_greedy'].sum()),
            'Greedy Pass%': f'{grp["correct_greedy"].sum()/n:.1%}',
        })
    # Totals row
    n = len(df)
    p1 = df['pass@1'].sum()
    p2 = df['pass@2'].sum()
    p3 = df['pass@3'].sum()
    gp = df['correct_greedy'].sum()
    rows.append({
        label: 'TOTAL',
        'N': n,
        'Pass@1': int(p1), 'Pass@1%': f'{p1/n:.1%}', 'Fail@1': int(n - p1),
        'Pass@2': int(p2), 'Pass@2%': f'{p2/n:.1%}', 'Fail@2': int(n - p2),
        'Pass@3': int(p3), 'Pass@3%': f'{p3/n:.1%}', 'Fail@3': int(n - p3),
        'Greedy Pass': int(gp), 'Greedy Pass%': f'{gp/n:.1%}',
    })
    return pd.DataFrame(rows)

# --- Per-Domain breakdown ---
print("=" * 80)
print("PER-DOMAIN BREAKDOWN")
print("=" * 80)
domain_table = _build_breakdown(results_df, 'domain', 'Domain')
display(domain_table)

# --- Per-Level breakdown ---
print("\n" + "=" * 80)
print("PER-LEVEL BREAKDOWN")
print("=" * 80)
level_table = _build_breakdown(results_df, 'level', 'Level')
display(level_table)
# Out:
# ================================================================================
# PER-DOMAIN BREAKDOWN
# ================================================================================
#           Domain    N  Pass@1 Pass@1%  Fail@1  Pass@2 Pass@2%  Fail@2  Pass@3  \
# 0        algebra  246      96   39.0%     150     127   51.6%     119     134
# 1  combinatorics   98      18   18.4%      80      23   23.5%      75      27
# 2       geometry   99      14   14.1%      85      18   18.2%      81      23
# 3  number_theory   49      14   28.6%      35      19   38.8%      30      19
# 4          TOTAL  492     142   28.9%     350     187   38.0%     305     203
#
#   Pass@3%  Fail@3  Greedy Pass Greedy Pass%
# 0   54.5%     112           96        39.0%
# 1   27.6%      71           18        18.4%
# 2   23.2%      76           14        14.1%
# 3   38.8%      30           14        28.6%
# 4   41.3%     289          142        28.9%
# ================================================================================
# PER-LEVEL BREAKDOWN
# ================================================================================
#    Level    N  Pass@1 Pass@1%  Fail@1  Pass@2 Pass@2%  Fail@2  Pass@3 Pass@3%  \
# 0      1   55      28   50.9%      27      36   65.5%      19      36   65.5%
# 1      2  255      94   36.9%     161     118   46.3%     137     129   50.6%
# 2      3  182      20   11.0%     162      33   18.1%     149      38   20.9%
# 3  TOTAL  492     142   28.9%     350     187   38.0%     305     203   41.3%
#
#    Fail@3  Greedy Pass Greedy Pass%
# 0      19           28        50.9%
# 1     126           94        36.9%
# 2     144           20        11.0%
# 3     289          142        28.9%

# %%
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
run_dir = OUTPUT_DIR / f"{MODEL_NAME}_{DATASET_NAME}_{timestamp}"
run_dir.mkdir(parents=True, exist_ok=True)

# --- Save full CSV + summary JSON ---
csv_path = run_dir / f"results.csv"
json_path = run_dir / f"summary.json"

results_df.to_csv(csv_path, index=False)
with open(json_path, 'w') as f:
    json.dump(summary, f, indent=2)

# --- Save per-domain & per-level tables ---
domain_table.to_csv(run_dir / "breakdown_domain.csv", index=False)
level_table.to_csv(run_dir / "breakdown_level.csv", index=False)

# --- Build JSONL records for passed / failed ---
def _best_attempt(row):
    """Return (code, result, attempt_label) for the best successful attempt, or the greedy attempt if all failed."""
    # Check greedy first
    if row.get('correct_greedy'):
        return row.get('code_greedy'), row.get('result_greedy'), 'greedy'
    # Check sampled attempts
    for j in range(1, N_SAMPLES + 1):
        if row.get(f'correct_{j}'):
            return row.get(f'code_{j}'), row.get(f'result_{j}'), f'sample_{j}'
    # All failed — return greedy as the representative attempt
    return row.get('code_greedy'), row.get('result_greedy'), 'greedy'

passed_records = []
failed_records = []

for _, row in results_df.iterrows():
    code, result, attempt_label = _best_attempt(row)

    rec = {
        'problem_id': row['problem_id'],
        'domain': row.get('domain', 'unknown'),
        'level': int(row.get('level', -1)),
        'problem': row['problem'],
        'expected_answer': row['answer'],
        'predicted_answer': result,
        'best_attempt': attempt_label,
        'code': code,
        'greedy_pass': bool(row.get('correct_greedy', False)),
        'pass@1': bool(row.get('pass@1', False)),
        'pass@3': bool(row.get('pass@3', False)),
        'greedy_code': row.get('code_greedy'),
        'greedy_result': row.get('result_greedy'),
        'greedy_error': row.get('error_greedy'),
    }
    # Include all sampled attempt details
    for j in range(1, N_SAMPLES + 1):
        rec[f'sample_{j}_code'] = row.get(f'code_{j}')
        rec[f'sample_{j}_result'] = row.get(f'result_{j}')
        rec[f'sample_{j}_correct'] = bool(row.get(f'correct_{j}', False))
        rec[f'sample_{j}_error'] = row.get(f'error_{j}')

    if row.get('pass@3', False):
        passed_records.append(rec)
    else:
        failed_records.append(rec)

# Write JSONL files
passed_path = run_dir / "passed.jsonl"
failed_path = run_dir / "failed.jsonl"

for path, records in [(passed_path, passed_records), (failed_path, failed_records)]:
    with open(path, 'w') as f:
        for rec in records:
            f.write(json.dumps(rec, default=str) + '\n')

print(f"Evaluation saved to: {run_dir}/")
print(f"  results.csv          ({len(results_df)} rows)")
print(f"  summary.json")
print(f"  breakdown_domain.csv")
print(f"  breakdown_level.csv")
print(f"  passed.jsonl         ({len(passed_records)} problems)")
print(f"  failed.jsonl         ({len(failed_records)} problems)")

print("\nSample (first 5):")
cols = ['problem_id', 'domain', 'level', 'pass@1', 'pass@3', 'correct_greedy', 'correct_1', 'correct_2', 'correct_3']
display(results_df[cols].head())
# Out:
# Evaluation saved to: evaluations/qwen_gemma_balanced_20260209_173642/
#   results.csv          (492 rows)
#   summary.json
#   breakdown_domain.csv
#   breakdown_level.csv
#   passed.jsonl         (203 problems)
#   failed.jsonl         (289 problems)
#
# Sample (first 5):
#   problem_id         domain  level  pass@1  pass@3  correct_greedy  correct_1  \
# 0       5472  number_theory      1    True    True            True       True
# 1       6357        algebra      1   False    True           False       True
# 2       4319        algebra      2    True    True            True       True
# 3        782        algebra      2    True    True            True       True
# 4       5260  combinatorics      2    True    True            True       True
#
#    correct_2  correct_3
# 0      False      False
# 1      False      False
# 2      False      False
# 3      False      False
# 4      False      False

# %% [markdown]
# ## Analysis

# %%
improved = results_df[(results_df['pass@1'] == False) & (results_df['pass@3'] == True)]
print(f"\nImproved by sampling: {len(improved)}/{N} ({len(improved)/N:.1%})")

if len(improved) > 0:
    print("\nFirst success distribution:")
    print(improved['first_success_attempt'].value_counts().sort_index())

failed_all = results_df[(results_df['pass@1'] == False) & (results_df['pass@3'] == False)]
print(f"\nFailed all attempts: {len(failed_all)}/{N}")

print("\nExecution failures:")
print(f"Greedy: {(~results_df['exec_ok_greedy']).sum()}")
for j in range(1, N_SAMPLES + 1):
    print(f"Sample {j}: {(~results_df[f'exec_ok_{j}']).sum()}")
# Out:
# Improved by sampling: 66/492 (13.4%)
#
# First success distribution:
# first_success_attempt
# 1.0    30
# 2.0    24
# 3.0    12
# Name: count, dtype: int64
#
# Failed all attempts: 284/492
#
# Execution failures:
# Greedy: 99
# Sample 1: 99
# Sample 2: 245
# Sample 3: 274

# %%
results_df[results_df['exec_ok_greedy'] == False].head()
# Out:
#    problem_id                                            problem answer  \
# 6         107  4. In the plane, there are 16 black points, as...      4
# 11         12  Randy has 60 mango trees on his farm. He also ...     85
# 18       4656  Bob and Johnny have a leaf raking business. Th...      9
# 24       4499  [\n\nThe Perimeter of a Triangle\n\nThe bisect...     85
# 29       3575  3. 3.1. Find the number of four-digit numbers ...     36
#
#            domain  level                                        code_greedy  \
# 6        geometry      3  def min_points(n):\n  count = 0\n  while True:...
# 11        algebra      1  num_coconut_trees = (60 // 2) - 5\ntotal_trees...
# 18        algebra      3  total_raked = 5 + 3\nmonday_earnings = 5 * 4\n...
# 24       geometry      3  from math import sqrt\n\ndef triangle_perimete...
# 29  number_theory      3  def count_divisible_by_15(digits):\n  count = ...
#
#     exec_ok_greedy result_greedy  \
# 6            False           NaN
# 11           False           NaN
# 18           False           NaN
# 24           False           NaN
# 29           False           NaN
#
#                                          error_greedy  correct_greedy  ...  \
# 6                                           No output           False  ...
# 11  Traceback (most recent call last):\n  File "/t...           False  ...
# 18                                          No output           False  ...
# 24  Traceback (most recent call last):\n  File "/t...           False  ...
# 29  Traceback (most recent call last):\n  File "/t...           False  ...
#
#                                               error_2  correct_2  \
# 6                                Skipped (early exit)      False
# 11  Traceback (most recent call last):\n  File "/t...      False
# 18    File "/tmp/tmp9gfw4ivt.py", line 1\n    tota...      False
# 24                                                NaN      False
# 29  Traceback (most recent call last):\n  File "/t...      False
#
#                                                code_3 exec_ok_3  result_3  \
# 6                                                 NaN     False       NaN
# 11  num_coconut_trees = (60 // 2) - 5\ntotal_trees...     False       NaN
# 18  total_raked_on_monday = 5\ntotal_raked_on_tues...      True         9
# 24  def triangle_perimeter(mn_np):\n  mp_length = ...      True        58
# 29  def count_numbers(digits):\n  count = 0\n  for...      True       600
#
#                                               error_3  correct_3 pass@1  \
# 6                                Skipped (early exit)      False  False
# 11  Traceback (most recent call last):\n  File "/t...      False  False
# 18                                                NaN       True  False
# 24                                                NaN      False  False
# 29                                                NaN      False  False
#
#    pass@3  first_success_attempt
# 6    True                    1.0
# 11  False                    NaN
# 18   True                    3.0
# 24  False                    NaN
# 29  False                    NaN
#
# [5 rows x 28 columns]
